# %% [markdown]
# <a href="https://colab.research.google.com/github/elgafar039-design/python/blob/main/01_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Python Overview
#
# Python is a high-level, interpreted, general-purpose programming language. It is known for its readability and simplicity, which makes it an excellent choice for beginners and experienced developers alike. Python supports multiple programming paradigms, including object-oriented, imperative, and functional programming.
#
# **Key Features of Python:**
#
# *   **Simple and Readable:** Python's syntax is designed to be clear and intuitive, resembling natural language more than other programming languages. This reduces the cost of program maintenance.
# *   **Versatile:** It can be used for web development (Django, Flask), data analysis and machine learning (Pandas, NumPy, Scikit-learn, TensorFlow), automation, scientific computing, game development, and more.
# *   **Interpreted Language:** Python code is executed line by line, which makes debugging easier and faster development cycles.
# *   **Dynamically Typed:** You don't need to declare the type of a variable when you create it; Python infers the type at runtime.
# *   **Cross-platform:** Python runs on various operating systems, including Windows, macOS, and Linux.
# *   **Extensive Libraries:** Python boasts a vast ecosystem of libraries and frameworks that extend its capabilities significantly.
#
# **Common Python Data Types:**
#
# *   **Numeric Types:** `int` (integers), `float` (floating-point numbers), `complex` (complex numbers).
# *   **Sequence Types:** `str` (strings), `list` (ordered, mutable sequences), `tuple` (ordered, immutable sequences).
# *   **Mapping Type:** `dict` (unordered collections of key-value pairs).
# *   **Set Types:** `set` (unordered collections of unique items), `frozenset` (immutable version of set).
# *   **Boolean Type:** `bool` (True or False).
#
# By having these distinct data types, Python (and programming languages in general) can efficiently store, manipulate, and process various kinds of information, leading to robust and functional applications.

# %%
i = 10       #this is an interger
f = 3.14       #this is a float
s = "Welcome to Python Class!"     #this is a string
is_true = True                #this is a boolean

print("Integer variable:", i)
print("Float variable:", f)
print("String variable:", s)
print("Boolean variable:", is_true)

# You can also find out the type of a variable
print("Type of the number is :", type(i))
print("Type of the word is :", type(s))
# Out:
# Integer variable: 10
# Float variable: 3.14
# String variable: Welcome to Python Class!
# Boolean variable: True
# Type of the number is : <class 'int'>
# Type of the word is : <class 'str'>

# %%
my_variable = None                       #Can we define a variable with an empty value?
print('The value of my_variable is ',my_variable)
# Out:
# The value of my_variable is  None

# %%
#evaluate any expression in Python, python returns the Boolean answer:



print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
x = 5
print(id(x))   # memory address of 5

x = 10
print(id(x))   # new memory address

# %%
x = 'Welcome'
print(x[3:])
# Out:
# come

# %%
#Python allows you to assign the same value to multiple variables in one line:

# %%
#assign values to multiple variables in one line:

# %%
#The best way to output multiple variables in the print() function is to separate them with commas, which even support different data types:

# %%
#Operations on number
x = 15
y = 4

print(x + y) #Addition
print(x - y) #Subtraction
print(x * y) #Multiplication
print(x / y) #Division
print(x % y) #Modulus
print(x ** y) #Exponentiation
print(x // y) #the floor division // rounds the result down to the nearest whole number

# %%
#built-in Methods

text = "GOOD Afternoon!"
print(text.upper())
print(text.lower())
# Out:
# GOOD AFTERNOON!
# good afternoon!

# %%
text = "hello!"
print (text.capitalize())

text = "GOOD Afternoon!"
print(text.casefold())

# %%
text = "     winter     "
print("Of all seasons", text, "is my favorite")
print("\n")

print("Of all seasons", text.strip(), "is my favorite")

newSeason = "winter"
newSeason = newSeason.replace("winter", "rainy")
print("Of all seasons", newSeason, "is my favorite")
# Out:
# Of all seasons      winter      is my favorite
#
#
# Of all seasons winter is my favorite
# Of all seasons rainy is my favorite

# %%
a = "Hello, World!"
print(a.split(","))

# %%
#string.count(value, start, end)
txt = "Rainbow is colorful"

x = txt.count("bow")

print(x)

text = "I love apples, apple are my favorite fruit"

x = text.count("apple", 10, 24)

print(x)

# %%
txt = "Hello, welcome to my world."

x = txt.find("welcome")

print(x)
# Out:
# 7

# %%
x='mango'
print(x)
print('The length of the text is',len(x))


print('The first character from the text is '+"'"+x[0]+"'")
print('The first character from the text is '+"'"+x[4]+"'")
# Out:
# mango
# The length of the text is 5
# The first character from the text is 'm'
# The first character from the text is 'o'

# %%
a = "Hello, World!"
print(a.split(","))

# %%
# Out:
# 1
# 1

# %%
#write a program to greet the user

name = input("Enter your name: ")
# Out:
# Enter your name: Auxi
# Hello Auxi! Welcome to Python Class.

# %%
txt = "Hello, welcome to my world."

x = txt.find("welcome")

print(x)

# %%
#Write a small profile generator

firstName = input("Enter your first name: ")
lastName = input("Enter your last name: ")
fullName= firstName+" "+lastName
hobby = input("What's your favourite hobby?")

print(fullName,'loves',hobby)
# Out:
# Enter your first name: Auxi
# Enter your last name: Fernando
# What's your favourite hobby?Photography
# Auxi Fernando loves Photography
